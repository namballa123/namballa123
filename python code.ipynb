# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we will explore various tools, languages, and libraries used in the field of data science. We will also demonstrate some basic arithmetic operations and unit conversions using Python code.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science Libraries
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool Name       | Category        |
# |----------------|-----------------|
# | Jupyter Notebook | IDE/Notebook     |
# | RStudio         | IDE              |
# | Apache Spark    | Big Data Framework |
# | TensorFlow      | Deep Learning    |
# | Tableau         | Visualization Tool |

# %% [markdown]
# ## Arithmetic Expressions in Python
# Below are examples of arithmetic expressions using Python, including multiplication and addition.

# %% [markdown]
# ## Author
# **Namballa Praveen**
